# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/Telco_Churn_Dataset.csv')

# %% [markdown]
# Pull library file into colab,
# Check to see if any duplicated cells,
# Check to see if any null cells,
# Check covariance between relating cells

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Length: 7043, dtype: bool

# %%
data.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
data.cov()
# Out:
#                 SeniorCitizen      tenure  MonthlyCharges
# SeniorCitizen        0.135875    0.149978        2.442062
# tenure               0.149978  603.168108      183.196987
# MonthlyCharges       2.442062  183.196987      905.410934
